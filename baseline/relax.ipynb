# %%
# !pip install git+https://github.com/BirkhoffG/jax-relax.git
# Out:
# Collecting git+https://github.com/BirkhoffG/jax-relax.git
#   Cloning https://github.com/BirkhoffG/jax-relax.git to /tmp/pip-req-build-htfut5wf
#   Running command git clone --filter=blob:none --quiet https://github.com/BirkhoffG/jax-relax.git /tmp/pip-req-build-htfut5wf
#   Resolved https://github.com/BirkhoffG/jax-relax.git to commit 9e70d353376bd075bd300970504daec4188b0bb2
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from jax-relax==0.2.9) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from jax-relax==0.2.9) (2.2.2)
# Requirement already satisfied: jax[cpu] in /usr/local/lib/python3.10/dist-packages (from jax-relax==0.2.9) (0.4.33)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from jax-relax==0.2.9) (4.66.6)
# Requirement already satisfied: optax in /usr/local/lib/python3.10/dist-packages (from jax-relax==0.2.9) (0.2.3)
# Requirement already satisfied: pydantic<2,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from jax-relax==0.2.9) (1.10.19)
# Requirement already satisfied: jax-tqdm in /usr/local/lib/python3.10/dist-packages (from jax-relax==0.2.9) (0.3.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from jax-relax==0.2.9) (0.8.0)
# Requirement already satisfied: keras<3.4.0,>=3.0.3 in /usr/local/lib/python3.10/dist-packages (from jax-relax==0.2.9) (3.3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from jax-relax==0.2.9) (3.8.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (from jax-relax==0.2.9) (0.13.2)
# Requirement already satisfied: dm-haiku<=0.0.12 in /usr/local/lib/python3.10/dist-packages (from jax-relax==0.2.9) (0.0.12)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from dm-haiku<=0.0.12->jax-relax==0.2.9) (1.4.0)
# Requirement already satisfied: jmp>=0.0.2 in /usr/local/lib/python3.10/dist-packages (from dm-haiku<=0.0.12->jax-relax==0.2.9) (0.0.4)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from dm-haiku<=0.0.12->jax-relax==0.2.9) (1.26.4)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from dm-haiku<=0.0.12->jax-relax==0.2.9) (0.9.0)
# Requirement already satisfied: flax>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from dm-haiku<=0.0.12->jax-relax==0.2.9) (0.8.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras<3.4.0,>=3.0.3->jax-relax==0.2.9) (13.9.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras<3.4.0,>=3.0.3->jax-relax==0.2.9) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras<3.4.0,>=3.0.3->jax-relax==0.2.9) (3.12.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras<3.4.0,>=3.0.3->jax-relax==0.2.9) (0.13.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras<3.4.0,>=3.0.3->jax-relax==0.2.9) (0.4.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2,>=1.9.0->jax-relax==0.2.9) (4.12.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->jax-relax==0.2.9) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->jax-relax==0.2.9) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->jax-relax==0.2.9) (3.5.0)
# Requirement already satisfied: chex<0.2.0,>=0.1.87 in /usr/local/lib/python3.10/dist-packages (from jax-tqdm->jax-relax==0.2.9) (0.1.87)
# Requirement already satisfied: jaxlib<=0.4.33,>=0.4.33 in /usr/local/lib/python3.10/dist-packages (from jax[cpu]->jax-relax==0.2.9) (0.4.33)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax[cpu]->jax-relax==0.2.9) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jax-relax==0.2.9) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jax-relax==0.2.9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jax-relax==0.2.9) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jax-relax==0.2.9) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jax-relax==0.2.9) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jax-relax==0.2.9) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jax-relax==0.2.9) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jax-relax==0.2.9) (2.8.2)
# Requirement already satisfied: etils[epy] in /usr/local/lib/python3.10/dist-packages (from optax->jax-relax==0.2.9) (1.10.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->jax-relax==0.2.9) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->jax-relax==0.2.9) (2024.2)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chex<0.2.0,>=0.1.87->jax-tqdm->jax-relax==0.2.9) (0.12.1)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.1->dm-haiku<=0.0.12->jax-relax==0.2.9) (1.1.0)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.1->dm-haiku<=0.0.12->jax-relax==0.2.9) (0.6.4)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.1->dm-haiku<=0.0.12->jax-relax==0.2.9) (0.1.67)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.10/dist-packages (from flax>=0.7.1->dm-haiku<=0.0.12->jax-relax==0.2.9) (6.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->jax-relax==0.2.9) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras<3.4.0,>=3.0.3->jax-relax==0.2.9) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras<3.4.0,>=3.0.3->jax-relax==0.2.9) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras<3.4.0,>=3.0.3->jax-relax==0.2.9) (0.1.2)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax>=0.7.1->dm-haiku<=0.0.12->jax-relax==0.2.9) (1.6.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax>=0.7.1->dm-haiku<=0.0.12->jax-relax==0.2.9) (3.20.3)
# Requirement already satisfied: humanize in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->flax>=0.7.1->dm-haiku<=0.0.12->jax-relax==0.2.9) (4.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epy]->optax->jax-relax==0.2.9) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epy]->optax->jax-relax==0.2.9) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epy]->optax->jax-relax==0.2.9) (3.20.2)

# %%
# !pip install nbdev
# Out:
# Requirement already satisfied: nbdev in /usr/local/lib/python3.10/dist-packages (2.3.31)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbdev) (24.1)
# Requirement already satisfied: fastcore>=1.5.27 in /usr/local/lib/python3.10/dist-packages (from nbdev) (1.7.19)
# Requirement already satisfied: execnb>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from nbdev) (0.1.6)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.10/dist-packages (from nbdev) (1.6.3)
# Requirement already satisfied: ghapi>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from nbdev) (1.0.6)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.10/dist-packages (from nbdev) (6.0.0)
# Requirement already satisfied: asttokens in /usr/local/lib/python3.10/dist-packages (from nbdev) (2.4.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from nbdev) (6.0.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from execnb>=0.1.4->nbdev) (7.34.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from asttokens->nbdev) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse->nbdev) (0.44.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->execnb>=0.1.4->nbdev) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->execnb>=0.1.4->nbdev) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->execnb>=0.1.4->nbdev) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->execnb>=0.1.4->nbdev) (0.2.13)

# %%
# !pip install pytorch_lightning
# Out:
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.5.0+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.66.6)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2024.10.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.5.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (24.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (0.11.8)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.10.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.10.0->pytorch_lightning) (75.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->pytorch_lightning) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1.0->pytorch_lightning) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics>=0.7.0->pytorch_lightning) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.10)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (0.2.0)

# %%
from relax.methods import VanillaCF
from relax import DataModule, MLModule, generate_cf_explanations, benchmark_cfs
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import functools as ft
import jax

# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
from pytorch_lightning import LightningModule, Trainer
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
from torchmetrics import Accuracy, MaxMetric

# Read and preprocess the data
dataframe = pd.read_csv('/content/final_novo.csv', sep=';')
dataframe = dataframe.drop(['Chave'], axis=1)
dataframe = dataframe.fillna(0)
dataframe['Anos educacao formal'] = dataframe['Anos educacao formal'].replace(-5, -1)
dataframe['sexo'].replace({'M': 0, 'F': 1}, inplace=True)

notears_selected = [
   "Suic_familia",
    "Capaz de tomar decisões importantes",
    "Estudante",
    "Hipocondriase",
    "Sentimentos_culpa",
    "Trabalho e interesses",
    'Dep_familia',
    'Alc_familia',
    'Capaz de desfrutar das coisas',
    'Droga',
    'Suicidio',
]

df_suic = dataframe[notears_selected].copy()
df_suic.dropna(inplace=True)
df_suic = df_suic.astype(int)

'''class MyDataset(Dataset):
    def __init__(self, input_dataframe, split="train", target="Suicidio", ignore_columns=[], train_ratio=0.8):
        self.split = split
        self.target = target
        self.ignore_columns = ignore_columns

        for coll in self.ignore_columns:
            if coll in input_dataframe.columns:
                input_dataframe = input_dataframe.drop(coll, axis=1)

        self.classification_dim = len(input_dataframe[self.target].unique())
        self.data_dim = len(input_dataframe.columns) - 1
        self.embedding_dim = input_dataframe.max().max() + 1

        y = input_dataframe[target].values
        x = input_dataframe.drop(target, axis=1).values

        self.x_train, self.x_test, self.y_train, self.y_test = train_test_split(x, y, test_size=1-train_ratio, random_state=42)

    def __len__(self):
        if self.split == "train":
            return len(self.x_train)
        elif self.split == "test":
            return len(self.x_test)
        else:
            raise ValueError("Split must be train or test")

    def __getitem__(self, idx):
        target = torch.zeros(self.classification_dim)
        if self.split == "train":
            target[self.y_train[idx]] = 1
            return (torch.tensor(self.x_train[idx]), target)
        elif self.split == "test":
            target[self.y_test[idx]] = 1
            return (torch.tensor(self.x_test[idx]), target)
        else:
            raise ValueError("Split must be train or test")

# Instantiate the dataset
train_dataset = MyDataset(df_suic, split="train", target="Suicidio", ignore_columns=[], train_ratio=0.8)
test_dataset = MyDataset(df_suic, split="test", target="Suicidio", ignore_columns=[], train_ratio=0.2)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)  # Shuffle training data
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

class MLP(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dim=128, n_layers=2):
        super(MLP, self).__init__()
        self.layers = nn.ModuleList()
        self.layers.append(nn.Linear(input_dim, hidden_dim))
        for i in range(n_layers - 1):
            self.layers.append(nn.Linear(hidden_dim, hidden_dim))
            self.layers.append(nn.Dropout(0.5))
            self.layers.append(nn.LeakyReLU())
        self.layers.append(nn.Linear(hidden_dim, output_dim))

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

class ClassificationModel(nn.Module):
    def __init__(self, input_dim, output_dim, embedding_dim, hidden_out, hidden_dim=128, n_layers=2):
        super(ClassificationModel, self).__init__()
        self.embedding_layer = nn.Embedding(embedding_dim, hidden_out)
        self.mlp = MLP(input_dim * hidden_out, output_dim, hidden_dim, n_layers)

    def forward(self, x):
        x = x.long()  # Ensure x is Long
        x = self.embedding_layer(x)
        x = x.view(x.shape[0], -1)
        x = self.mlp(x)
        return F.softmax(x, dim=1)

class BaseModel(LightningModule):
    def __init__(self, input_dim, output_dim, embedding_dim, embedding_out, hidden_dim):
        super().__init__()
        self.model = ClassificationModel(input_dim, output_dim, embedding_dim, embedding_out, hidden_dim=hidden_dim, n_layers=2)
        self.lr = 1e-3
        self.save_hyperparameters()
        self.accuracy = Accuracy(task='multiclass',num_classes=5)  # Corrigir para o número certo de classes (0 a 4)
        self.val_acc_best = MaxMetric()

    def forward(self, x):
        return self.model(x)

    def step(self, batch):
        x, y = batch
        y_hat = self(x).squeeze()
        loss = F.cross_entropy(y_hat, y.argmax(dim=1))  # Use cross entropy
        acc = self.accuracy(y_hat, y.argmax(dim=1))
        return loss, acc

    def training_step(self, batch, batch_idx):
        loss, acc = self.step(batch)
        self.log('train_loss', loss)
        self.log('train_acc', acc)
        return loss

    def validation_step(self, batch, batch_idx):
        loss, acc = self.step(batch)
        self.log('val_loss', loss)
        self.log('val_acc', acc)
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=self.lr)

    def pred_fn(X):
      model.eval()  # Colocar o modelo em modo de avaliação
      with torch.no_grad():
          X_tensor = torch.FloatTensor(X)  # Converter para tensor
          return model(X_tensor).numpy()  # Retornar como numpy array

# Initialize model
model = BaseModel(
    input_dim=train_dataset.data_dim,
    output_dim=train_dataset.classification_dim,
    embedding_dim=100,
    embedding_out=64,
    hidden_dim=128
)

# Initialize callbacks
checkpoint_callback = ModelCheckpoint(monitor='val_loss', dirpath='checkpoints/', filename='best-checkpoint', save_top_k=1, mode='min')
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.05, patience=10, mode='min')

# Initialize a trainer
trainer = Trainer(
    devices=1,
    check_val_every_n_epoch=10,
    log_every_n_steps=10,
    callbacks=[checkpoint_callback, early_stopping],
    enable_progress_bar=False
)

# Train the model
trainer.fit(model, train_loader, test_loader)'''
# Out:
# <ipython-input-5-e22ab4e898e8>:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe['sexo'].replace({'M': 0, 'F': 1}, inplace=True)
# <ipython-input-5-e22ab4e898e8>:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataframe['sexo'].replace({'M': 0, 'F': 1}, inplace=True)
# 'class MyDataset(Dataset):\n    def __init__(self, input_dataframe, split="train", target="Suicidio", ignore_columns=[], train_ratio=0.8):\n        self.split = split\n        self.target = target\n        self.ignore_columns = ignore_columns\n\n        for coll in self.ignore_columns:\n            if coll in input_dataframe.columns:\n                input_dataframe = input_dataframe.drop(coll, axis=1)\n\n        self.classification_dim = len(input_dataframe[self.target].unique())\n        self.data_dim = len(input_dataframe.columns) - 1\n        self.embedding_dim = input_dataframe.max().max() + 1\n\n        y = input_dataframe[target].values\n        x = input_dataframe.drop(target, axis=1).values\n\n        self.x_train, self.x_test, self.y_train, self.y_test = train_test_split(x, y, test_size=1-train_ratio, random_state=42)\n\n    def __len__(self):\n        if self.split == "train":\n            return len(self.x_train)\n        elif self.split == "test":\n            return len(self.x_test)\n        else:\n            raise ValueError("Split must be train or test")\n\n    def __getitem__(self, idx):\n        target = torch.zeros(self.classification_dim)\n        if self.split == "train":\n            target[self.y_train[idx]] = 1\n            return (torch.tensor(self.x_train[idx]), target)\n        elif self.split == "test":\n            target[self.y_test[idx]] = 1\n            return (torch.tensor(self.x_test[idx]), target)\n        else:\n            raise ValueError("Split must be train or test")\n\n# Instantiate the dataset\ntrain_dataset = MyDataset(df_suic, split="train", target="Suicidio", ignore_columns=[], train_ratio=0.8)\ntest_dataset = MyDataset(df_suic, split="test", target="Suicidio", ignore_columns=[], train_ratio=0.2)\n\ntrain_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)  # Shuffle training data\ntest_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)\n\nclass MLP(nn.Module):\n    def __init__(self, input_dim, output_dim, hidden_dim=128, n_layers=2):\n        super(MLP, self).__init__()\n        self.layers = nn.ModuleList()\n        self.layers.append(nn.Linear(input_dim, hidden_dim))\n        for i in range(n_layers - 1):\n            self.layers.append(nn.Linear(hidden_dim, hidden_dim))\n            self.layers.append(nn.Dropout(0.5))\n            self.layers.append(nn.LeakyReLU())\n        self.layers.append(nn.Linear(hidden_dim, output_dim))\n\n    def forward(self, x):\n        for layer in self.layers:\n            x = layer(x)\n        return x\n\nclass ClassificationModel(nn.Module):\n    def __init__(self, input_dim, output_dim, embedding_dim, hidden_out, hidden_dim=128, n_layers=2):\n        super(ClassificationModel, self).__init__()\n        self.embedding_layer = nn.Embedding(embedding_dim, hidden_out)\n        self.mlp = MLP(input_dim * hidden_out, output_dim, hidden_dim, n_layers)\n\n    def forward(self, x):\n        x = x.long()  # Ensure x is Long\n        x = self.embedding_layer(x)\n        x = x.view(x.shape[0], -1)\n        x = self.mlp(x)\n        return F.softmax(x, dim=1)\n\nclass BaseModel(LightningModule):\n    def __init__(self, input_dim, output_dim, embedding_dim, embedding_out, hidden_dim):\n        super().__init__()\n        self.model = ClassificationModel(input_dim, output_dim, embedding_dim, embedding_out, hidden_dim=hidden_dim, n_layers=2)\n        self.lr = 1e-3\n        self.save_hyperparameters()\n        self.accuracy = Accuracy(task=\'multiclass\',num_classes=5)  # Corrigir para o número certo de classes (0 a 4)\n        self.val_acc_best = MaxMetric()\n\n    def forward(self, x):\n        return self.model(x)\n\n    def step(self, batch):\n        x, y = batch\n        y_hat = self(x).squeeze()\n        loss = F.cross_entropy(y_hat, y.argmax(dim=1))  # Use cross entropy\n        acc = self.accuracy(y_hat, y.argmax(dim=1))\n        return loss, acc\n\n    def training_step(self, batch, batch_idx):\n        loss, acc = self.step ...

# %%
'''def predic_fn(X):
    if not isinstance(X, np.ndarray):
        X = np.array(X)  # Converta para um array NumPy

    model.eval()  # Colocar o modelo em modo de avaliação
    with torch.no_grad():
        if X.ndim == 1:
            X = np.expand_dims(X, axis=0)  # Adiciona uma nova dimensão

        X_tensor = torch.FloatTensor(X)  # Converter para tensor
        return model(X_tensor).numpy()  # Retornar como numpy array
'''
# Out:
# 'def predic_fn(X):\n    if not isinstance(X, np.ndarray):\n        X = np.array(X)  # Converta para um array NumPy\n\n    model.eval()  # Colocar o modelo em modo de avaliação\n    with torch.no_grad():\n        if X.ndim == 1:\n            X = np.expand_dims(X, axis=0)  # Adiciona uma nova dimensão\n\n        X_tensor = torch.FloatTensor(X)  # Converter para tensor\n        return model(X_tensor).numpy()  # Retornar como numpy array\n'

# %%
'''train_dataset.x_test[0].astype(float)
X_tensor = torch.tensor(train_dataset.x_test[0], dtype=torch.float32)  # `device` pode ser 'cpu' ou 'cuda'
'''
# Out:
# "train_dataset.x_test[0].astype(float)\nX_tensor = torch.tensor(train_dataset.x_test[0], dtype=torch.float32)  # `device` pode ser 'cpu' ou 'cuda'\n"

# %%
'''def pred_fn( x):
        x = torch.LongTensor(X.values).to(model.device)
        return model(x)
cf = vcf.generate_cf(X_test[:1], pred_fn, permit_int=True)'''
# Out:
# 'def pred_fn( x):\n        x = torch.LongTensor(X.values).to(model.device)\n        return model(x)\ncf = vcf.generate_cf(X_test[:1], pred_fn, permit_int=True)'

# %%
df_suic['Suicidio']=np.where((df_suic['Suicidio'] >1),1,0)
target = "Suicidio"
X = df_suic.drop(columns=[target])
y = df_suic[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model1 = MLModule()
model1.train((X_train, y_train), epochs=500, batch_size=64)
# Out:
# Epoch 1/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.6251 - loss: 1.2037
# Epoch 2/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.6962 - loss: 0.6677
# Epoch 3/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7084 - loss: 0.6229
# Epoch 4/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7239 - loss: 0.6160
# Epoch 5/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7542 - loss: 0.5874
# Epoch 6/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7431 - loss: 0.5879
# Epoch 7/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7460 - loss: 0.5845
# Epoch 8/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7672 - loss: 0.5664
# Epoch 9/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7695 - loss: 0.5664
# Epoch 10/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7682 - loss: 0.5632
# Epoch 11/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7660 - loss: 0.5572
# Epoch 12/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7675 - loss: 0.5523
# Epoch 13/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7587 - loss: 0.5619
# Epoch 14/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7690 - loss: 0.5512
# Epoch 15/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7600 - loss: 0.5578
# Epoch 16/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7556 - loss: 0.5643
# Epoch 17/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7698 - loss: 0.5412
# Epoch 18/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7676 - loss: 0.5433
# Epoch 19/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7690 - loss: 0.5464
# Epoch 20/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7617 - loss: 0.5478
# Epoch 21/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7694 - loss: 0.5430
# Epoch 22/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7597 - loss: 0.5513
# Epoch 23/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7456 - loss: 0.5684
# Epoch 24/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7648 - loss: 0.5440
# Epoch 25/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7588 - loss: 0.5535
# Epoch 26/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7606 - loss: 0.5433
# Epoch 27/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7587 - loss: 0.5397
# Epoch 28/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7576 - loss: 0.5444
# Epoch 29/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7572 - loss: 0.5481
# Epoch 30/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7657 - loss: 0.5363
# Epoch 31/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7603 - loss: 0.5483
# Epoch 32/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7656 - loss: 0.5470
# Epoch 33/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7638 - loss: 0.5309
# Epoch 34/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7674 - loss: 0.5328
# Epoch 35/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7665 - loss: 0.5319
# Epoch 36/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7556 - loss: 0.5444
# Epoch 37/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7696 - loss: 0.5324
# Epoch 38/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7557 - loss: 0.5424
# Epoch 39/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7661 - loss: 0.5310
# Epoch 40/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7613 - loss: 0.5341
# Epoch 41/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7599 - loss: 0.5373
# Epoch 42/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7558 - loss: 0.5440
# Epoch 43/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7607 - loss: 0.5401
# Epoch 44/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7413 - loss: 0.5570
# Epoch 45/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7605 - loss: 0.5318
# Epoch 46/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7636 - loss: 0.5307
# Epoch 47/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7638 - loss: 0.5373
# Epoch 48/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7583 - loss: 0.5394
# Epoch 49/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7697 - loss: 0.5384
# Epoch 50/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7597 - loss: 0.5319
# Epoch 51/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7628 - loss: 0.5306
# Epoch 52/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7574 - loss: 0.5334
# Epoch 53/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7517 - loss: 0.5453
# Epoch 54/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7670 - loss: 0.5288
# Epoch 55/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7483 - loss: 0.5510
# Epoch 56/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7697 - loss: 0.5191
# Epoch 57/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7625 - loss: 0.5309
# Epoch 58/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7635 - loss: 0.5305
# Epoch 59/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7654 - loss: 0.5272
# Epoch 60/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7556 - loss: 0.5359
# Epoch 61/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7626 - loss: 0.5316
# Epoch 62/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7565 - loss: 0.5351
# Epoch 63/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7743 - loss: 0.5151
# Epoch 64/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7617 - loss: 0.5288
# Epoch 65/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7536 - loss: 0.5434
# Epoch 66/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7672 - loss: 0.5285
# Epoch 67/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7549 - loss: 0.5379
# Epoch 68/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7607 - loss: 0.5348
# Epoch 69/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7641 - loss: 0.5350
# Epoch 70/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7553 - loss: 0.5404
# Epoch 71/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7701 - loss: 0.5183
# Epoch 72/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7653 - loss: 0.5352
# Epoch 73/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7753 - loss: 0.5187
# Epoch 74/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7600 - loss: 0.5286
# Epoch 75/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7627 - loss: 0.5290
# Epoch 76/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7601 - loss: 0.5283
# Epoch 77/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7694 - loss: 0.5284
# Epoch 78/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7522 - loss: 0.5484
# Epoch 79/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7674 - loss: 0.5306
# Epoch 80/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7629 - loss: 0.5301
# Epoch 81/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7594 - loss: 0.5324
# Epoch 82/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7684 - loss: 0.5236
# Epoch 83/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7623 - loss: 0.5301
# Epoch 84/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7641 - loss: 0.5262
# Epoch 85/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7723 - loss: 0.5124
# Epoch 86/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7558 - loss: 0.5423
# Epoch 87/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7554 - loss: 0.5382
# Epoch 88/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7605 - loss: 0.5284
# Epoch 89/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7549 - loss: 0.5363
# Epoch 90/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7675 - loss: 0.5225
# Epoch 91/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7718 - loss: 0.5219
# Epoch 92/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7630 - loss: 0.5307
# Epoch 93/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7597 - loss: 0.5348
# Epoch 94/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7633 - loss: 0.5239
# Epoch 95/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7665 - loss: 0.5293
# Epoch 96/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7540 - loss: 0.5295
# Epoch 97/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7577 - loss: 0.5334
# Epoch 98/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7685 - loss: 0.5203
# Epoch 99/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7612 - loss: 0.5347
# Epoch 100/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7495 - loss: 0.5319
# Epoch 101/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7696 - loss: 0.5247
# Epoch 102/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7670 - loss: 0.5234
# Epoch 103/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7716 - loss: 0.5151
# Epoch 104/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7609 - loss: 0.5339
# Epoch 105/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7816 - loss: 0.5041
# Epoch 106/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7608 - loss: 0.5315
# Epoch 107/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7580 - loss: 0.5366
# Epoch 108/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7618 - loss: 0.5282
# Epoch 109/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7606 - loss: 0.5244
# Epoch 110/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7572 - loss: 0.5406
# Epoch 111/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7484 - loss: 0.5414
# Epoch 112/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7575 - loss: 0.5339
# Epoch 113/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7549 - loss: 0.5425
# Epoch 114/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7647 - loss: 0.5254
# Epoch 115/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7608 - loss: 0.5312
# Epoch 116/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7644 - loss: 0.5196
# Epoch 117/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7588 - loss: 0.5244
# Epoch 118/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7761 - loss: 0.5170
# Epoch 119/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7648 - loss: 0.5267
# Epoch 120/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7580 - loss: 0.5344
# Epoch 121/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7644 - loss: 0.5273
# Epoch 122/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7588 - loss: 0.5295
# Epoch 123/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7530 - loss: 0.5387
# Epoch 124/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7660 - loss: 0.5254
# Epoch 125/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7629 - loss: 0.5294
# Epoch 126/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7660 - loss: 0.5265
# Epoch 127/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7709 - loss: 0.5245
# Epoch 128/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7666 - loss: 0.5191
# Epoch 129/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7611 - loss: 0.5161
# Epoch 130/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7409 - loss: 0.5551
# Epoch 131/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7750 - loss: 0.5176
# Epoch 132/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7681 - loss: 0.5153
# Epoch 133/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7649 - loss: 0.5261
# Epoch 134/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7600 - loss: 0.5255
# Epoch 135/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7778 - loss: 0.5125
# Epoch 136/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7581 - loss: 0.5339
# Epoch 137/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7676 - loss: 0.5244
# Epoch 138/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7566 - loss: 0.5373
# Epoch 139/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7712 - loss: 0.5189
# Epoch 140/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7579 - loss: 0.5484
# Epoch 141/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7532 - loss: 0.5307
# Epoch 142/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7528 - loss: 0.5354
# Epoch 143/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7793 - loss: 0.5080
# Epoch 144/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7703 - loss: 0.5158
# Epoch 145/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7676 - loss: 0.5141
# Epoch 146/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7640 - loss: 0.5302
# Epoch 147/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7559 - loss: 0.5351
# Epoch 148/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7631 - loss: 0.5270
# Epoch 149/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7608 - loss: 0.5321
# Epoch 150/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7702 - loss: 0.5157
# Epoch 151/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7728 - loss: 0.5219
# Epoch 152/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7606 - loss: 0.5305
# Epoch 153/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7553 - loss: 0.5306
# Epoch 154/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7629 - loss: 0.5192
# Epoch 155/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7726 - loss: 0.5120
# Epoch 156/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7599 - loss: 0.5271
# Epoch 157/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7677 - loss: 0.5230
# Epoch 158/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7628 - loss: 0.5258
# Epoch 159/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7624 - loss: 0.5255
# Epoch 160/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7665 - loss: 0.5251
# Epoch 161/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7588 - loss: 0.5285
# Epoch 162/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7692 - loss: 0.5284
# Epoch 163/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7632 - loss: 0.5150
# Epoch 164/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7545 - loss: 0.5301
# Epoch 165/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7621 - loss: 0.5297
# Epoch 166/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7641 - loss: 0.5196
# Epoch 167/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7663 - loss: 0.5217
# Epoch 168/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7606 - loss: 0.5276
# Epoch 169/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7508 - loss: 0.5389
# Epoch 170/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7622 - loss: 0.5286
# Epoch 171/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7659 - loss: 0.5223
# Epoch 172/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7659 - loss: 0.5203
# Epoch 173/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7488 - loss: 0.5427
# Epoch 174/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7691 - loss: 0.5263
# Epoch 175/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7684 - loss: 0.5189
# Epoch 176/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7691 - loss: 0.5253
# Epoch 177/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7681 - loss: 0.5196
# Epoch 178/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7698 - loss: 0.5110
# Epoch 179/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7404 - loss: 0.5402
# Epoch 180/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7724 - loss: 0.5138
# Epoch 181/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7809 - loss: 0.5040
# Epoch 182/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7572 - loss: 0.5302
# Epoch 183/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7775 - loss: 0.5060
# Epoch 184/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7665 - loss: 0.5187
# Epoch 185/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7564 - loss: 0.5290
# Epoch 186/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7732 - loss: 0.5145
# Epoch 187/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7694 - loss: 0.5180
# Epoch 188/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7539 - loss: 0.5354
# Epoch 189/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7681 - loss: 0.5166
# Epoch 190/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7512 - loss: 0.5410
# Epoch 191/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7525 - loss: 0.5352
# Epoch 192/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7566 - loss: 0.5294
# Epoch 193/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7691 - loss: 0.5173
# Epoch 194/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7707 - loss: 0.5141
# Epoch 195/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7756 - loss: 0.5120
# Epoch 196/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7678 - loss: 0.5092
# Epoch 197/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7617 - loss: 0.5264
# Epoch 198/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7595 - loss: 0.5267
# Epoch 199/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7658 - loss: 0.5150
# Epoch 200/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7657 - loss: 0.5267
# Epoch 201/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7651 - loss: 0.5241
# Epoch 202/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7522 - loss: 0.5389
# Epoch 203/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7597 - loss: 0.5215
# Epoch 204/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7610 - loss: 0.5250
# Epoch 205/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7633 - loss: 0.5229
# Epoch 206/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7587 - loss: 0.5285
# Epoch 207/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7577 - loss: 0.5263
# Epoch 208/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7542 - loss: 0.5370
# Epoch 209/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7711 - loss: 0.5198
# Epoch 210/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7612 - loss: 0.5236
# Epoch 211/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7585 - loss: 0.5221
# Epoch 212/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7590 - loss: 0.5305
# Epoch 213/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7637 - loss: 0.5220
# Epoch 214/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7643 - loss: 0.5158
# Epoch 215/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7650 - loss: 0.5136
# Epoch 216/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7737 - loss: 0.5100
# Epoch 217/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7605 - loss: 0.5233
# Epoch 218/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7719 - loss: 0.5083
# Epoch 219/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7642 - loss: 0.5222
# Epoch 220/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7513 - loss: 0.5335
# Epoch 221/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7661 - loss: 0.5202
# Epoch 222/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7714 - loss: 0.5210
# Epoch 223/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7691 - loss: 0.5112
# Epoch 224/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7798 - loss: 0.5088
# Epoch 225/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7640 - loss: 0.5174
# Epoch 226/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7645 - loss: 0.5181
# Epoch 227/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7669 - loss: 0.5153
# Epoch 228/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7558 - loss: 0.5338
# Epoch 229/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7561 - loss: 0.5213
# Epoch 230/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7524 - loss: 0.5373
# Epoch 231/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7664 - loss: 0.5186
# Epoch 232/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7639 - loss: 0.5111
# Epoch 233/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7617 - loss: 0.5299
# Epoch 234/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7743 - loss: 0.5086
# Epoch 235/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7613 - loss: 0.5235
# Epoch 236/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7663 - loss: 0.5190
# Epoch 237/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7707 - loss: 0.5084
# Epoch 238/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7665 - loss: 0.5153
# Epoch 239/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7594 - loss: 0.5229
# Epoch 240/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7569 - loss: 0.5318
# Epoch 241/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7707 - loss: 0.5107
# Epoch 242/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7612 - loss: 0.5181
# Epoch 243/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7558 - loss: 0.5260
# Epoch 244/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7590 - loss: 0.5261
# Epoch 245/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7616 - loss: 0.5259
# Epoch 246/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7512 - loss: 0.5326
# Epoch 247/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7582 - loss: 0.5217
# Epoch 248/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7578 - loss: 0.5269
# Epoch 249/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7607 - loss: 0.5228
# Epoch 250/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7623 - loss: 0.5313
# Epoch 251/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7715 - loss: 0.5174
# Epoch 252/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7425 - loss: 0.5452
# Epoch 253/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7727 - loss: 0.5144
# Epoch 254/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7810 - loss: 0.5046
# Epoch 255/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7578 - loss: 0.5191
# Epoch 256/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7603 - loss: 0.5213
# Epoch 257/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7657 - loss: 0.5186
# Epoch 258/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7549 - loss: 0.5372
# Epoch 259/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7684 - loss: 0.5250
# Epoch 260/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7526 - loss: 0.5289
# Epoch 261/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7634 - loss: 0.5178
# Epoch 262/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7649 - loss: 0.5186
# Epoch 263/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7603 - loss: 0.5224
# Epoch 264/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7775 - loss: 0.5123
# Epoch 265/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7566 - loss: 0.5293
# Epoch 266/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7774 - loss: 0.5052
# Epoch 267/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7564 - loss: 0.5353
# Epoch 268/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7584 - loss: 0.5306
# Epoch 269/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7751 - loss: 0.5130
# Epoch 270/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7541 - loss: 0.5330
# Epoch 271/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7622 - loss: 0.5261
# Epoch 272/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7681 - loss: 0.5171
# Epoch 273/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7662 - loss: 0.5187
# Epoch 274/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7616 - loss: 0.5231
# Epoch 275/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7614 - loss: 0.5218
# Epoch 276/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7642 - loss: 0.5171
# Epoch 277/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7682 - loss: 0.5095
# Epoch 278/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7640 - loss: 0.5127
# Epoch 279/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7651 - loss: 0.5159
# Epoch 280/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7573 - loss: 0.5234
# Epoch 281/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7771 - loss: 0.5090
# Epoch 282/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7683 - loss: 0.5144
# Epoch 283/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7660 - loss: 0.5125
# Epoch 284/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7531 - loss: 0.5293
# Epoch 285/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7616 - loss: 0.5134
# Epoch 286/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7653 - loss: 0.5155
# Epoch 287/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7703 - loss: 0.5196
# Epoch 288/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7540 - loss: 0.5305
# Epoch 289/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7607 - loss: 0.5233
# Epoch 290/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7581 - loss: 0.5321
# Epoch 291/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7670 - loss: 0.5137
# Epoch 292/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7736 - loss: 0.5081
# Epoch 293/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7698 - loss: 0.5188
# Epoch 294/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7562 - loss: 0.5272
# Epoch 295/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7596 - loss: 0.5261
# Epoch 296/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7659 - loss: 0.5117
# Epoch 297/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7661 - loss: 0.5175
# Epoch 298/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7681 - loss: 0.5154
# Epoch 299/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7480 - loss: 0.5355
# Epoch 300/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7715 - loss: 0.5062
# Epoch 301/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7789 - loss: 0.5035
# Epoch 302/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7802 - loss: 0.4997
# Epoch 303/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7583 - loss: 0.5262
# Epoch 304/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7733 - loss: 0.5070
# Epoch 305/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7692 - loss: 0.5121
# Epoch 306/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7588 - loss: 0.5247
# Epoch 307/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7674 - loss: 0.5106
# Epoch 308/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7555 - loss: 0.5331
# Epoch 309/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7639 - loss: 0.5087
# Epoch 310/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7679 - loss: 0.5143
# Epoch 311/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7708 - loss: 0.5160
# Epoch 312/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7578 - loss: 0.5254
# Epoch 313/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7681 - loss: 0.5188
# Epoch 314/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7617 - loss: 0.5196
# Epoch 315/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7615 - loss: 0.5241
# Epoch 316/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7534 - loss: 0.5281
# Epoch 317/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7653 - loss: 0.5131
# Epoch 318/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7707 - loss: 0.5169
# Epoch 319/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7722 - loss: 0.5100
# Epoch 320/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7699 - loss: 0.5154
# Epoch 321/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7625 - loss: 0.5181
# Epoch 322/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7596 - loss: 0.5239
# Epoch 323/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7551 - loss: 0.5286
# Epoch 324/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7551 - loss: 0.5227
# Epoch 325/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7636 - loss: 0.5210
# Epoch 326/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7769 - loss: 0.5058
# Epoch 327/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7615 - loss: 0.5171
# Epoch 328/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7552 - loss: 0.5320
# Epoch 329/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7702 - loss: 0.5110
# Epoch 330/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7513 - loss: 0.5311
# Epoch 331/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7587 - loss: 0.5213
# Epoch 332/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7574 - loss: 0.5279
# Epoch 333/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7596 - loss: 0.5275
# Epoch 334/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7613 - loss: 0.5180
# Epoch 335/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7461 - loss: 0.5411
# Epoch 336/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7588 - loss: 0.5248
# Epoch 337/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7784 - loss: 0.5027
# Epoch 338/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7649 - loss: 0.5138
# Epoch 339/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7590 - loss: 0.5198
# Epoch 340/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7635 - loss: 0.5281
# Epoch 341/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7741 - loss: 0.5026
# Epoch 342/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7601 - loss: 0.5248
# Epoch 343/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7644 - loss: 0.5160
# Epoch 344/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7441 - loss: 0.5434
# Epoch 345/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7615 - loss: 0.5308
# Epoch 346/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7676 - loss: 0.5189
# Epoch 347/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7691 - loss: 0.5092
# Epoch 348/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7650 - loss: 0.5188
# Epoch 349/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7687 - loss: 0.5123
# Epoch 350/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7633 - loss: 0.5166
# Epoch 351/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7623 - loss: 0.5244
# Epoch 352/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7522 - loss: 0.5237
# Epoch 353/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7695 - loss: 0.5117
# Epoch 354/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7603 - loss: 0.5151
# Epoch 355/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7722 - loss: 0.5081
# Epoch 356/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7418 - loss: 0.5318
# Epoch 357/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7648 - loss: 0.5143
# Epoch 358/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7804 - loss: 0.5026
# Epoch 359/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7607 - loss: 0.5280
# Epoch 360/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7675 - loss: 0.5129
# Epoch 361/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7625 - loss: 0.5232
# Epoch 362/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7768 - loss: 0.5135
# Epoch 363/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7590 - loss: 0.5175
# Epoch 364/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7651 - loss: 0.5208
# Epoch 365/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7633 - loss: 0.5231
# Epoch 366/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7610 - loss: 0.5205
# Epoch 367/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7712 - loss: 0.5139
# Epoch 368/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7601 - loss: 0.5177
# Epoch 369/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7731 - loss: 0.5144
# Epoch 370/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7619 - loss: 0.5226
# Epoch 371/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7638 - loss: 0.5239
# Epoch 372/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7721 - loss: 0.5090
# Epoch 373/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7699 - loss: 0.5071
# Epoch 374/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7543 - loss: 0.5190
# Epoch 375/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7577 - loss: 0.5262
# Epoch 376/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7596 - loss: 0.5118
# Epoch 377/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7646 - loss: 0.5164
# Epoch 378/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7726 - loss: 0.5158
# Epoch 379/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7647 - loss: 0.5229
# Epoch 380/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7573 - loss: 0.5142
# Epoch 381/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7717 - loss: 0.5038
# Epoch 382/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7618 - loss: 0.5132
# Epoch 383/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7516 - loss: 0.5262
# Epoch 384/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7615 - loss: 0.5322
# Epoch 385/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7647 - loss: 0.5128
# Epoch 386/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7544 - loss: 0.5215
# Epoch 387/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7544 - loss: 0.5289
# Epoch 388/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7601 - loss: 0.5129
# Epoch 389/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7470 - loss: 0.5351
# Epoch 390/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7672 - loss: 0.5073
# Epoch 391/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7503 - loss: 0.5307
# Epoch 392/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7706 - loss: 0.5094
# Epoch 393/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7645 - loss: 0.5149
# Epoch 394/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7640 - loss: 0.5120
# Epoch 395/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7553 - loss: 0.5300
# Epoch 396/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7648 - loss: 0.5106
# Epoch 397/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7626 - loss: 0.5165
# Epoch 398/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7628 - loss: 0.5202
# Epoch 399/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7708 - loss: 0.5127
# Epoch 400/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7595 - loss: 0.5279
# Epoch 401/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7681 - loss: 0.5151
# Epoch 402/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7708 - loss: 0.5158
# Epoch 403/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7612 - loss: 0.5270
# Epoch 404/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7553 - loss: 0.5342
# Epoch 405/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7600 - loss: 0.5222
# Epoch 406/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7650 - loss: 0.5161
# Epoch 407/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7701 - loss: 0.5087
# Epoch 408/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7607 - loss: 0.5212
# Epoch 409/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7545 - loss: 0.5268
# Epoch 410/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7744 - loss: 0.5100
# Epoch 411/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7511 - loss: 0.5289
# Epoch 412/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7648 - loss: 0.5115
# Epoch 413/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7506 - loss: 0.5320
# Epoch 414/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7636 - loss: 0.5206
# Epoch 415/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7600 - loss: 0.5204
# Epoch 416/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7681 - loss: 0.5109
# Epoch 417/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7681 - loss: 0.5094
# Epoch 418/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7557 - loss: 0.5280
# Epoch 419/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7553 - loss: 0.5294
# Epoch 420/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7724 - loss: 0.5048
# Epoch 421/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7676 - loss: 0.5122
# Epoch 422/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7663 - loss: 0.5142
# Epoch 423/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7560 - loss: 0.5248
# Epoch 424/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7723 - loss: 0.5115
# Epoch 425/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7616 - loss: 0.5183
# Epoch 426/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7599 - loss: 0.5175
# Epoch 427/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7660 - loss: 0.5182
# Epoch 428/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7573 - loss: 0.5213
# Epoch 429/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7669 - loss: 0.5118
# Epoch 430/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7704 - loss: 0.5025
# Epoch 431/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7670 - loss: 0.5115
# Epoch 432/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7652 - loss: 0.5331
# Epoch 433/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7552 - loss: 0.5271
# Epoch 434/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7769 - loss: 0.4966
# Epoch 435/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7635 - loss: 0.5175
# Epoch 436/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7649 - loss: 0.5168
# Epoch 437/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7553 - loss: 0.5297
# Epoch 438/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7684 - loss: 0.5155
# Epoch 439/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7525 - loss: 0.5317
# Epoch 440/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7734 - loss: 0.5023
# Epoch 441/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7740 - loss: 0.5063
# Epoch 442/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7584 - loss: 0.5175
# Epoch 443/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7726 - loss: 0.5101
# Epoch 444/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7580 - loss: 0.5208
# Epoch 445/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7742 - loss: 0.4992
# Epoch 446/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7576 - loss: 0.5240
# Epoch 447/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7712 - loss: 0.5127
# Epoch 448/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7628 - loss: 0.5164
# Epoch 449/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7672 - loss: 0.5188
# Epoch 450/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7705 - loss: 0.5100
# Epoch 451/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7728 - loss: 0.5032
# Epoch 452/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7669 - loss: 0.5225
# Epoch 453/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7672 - loss: 0.5156
# Epoch 454/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7660 - loss: 0.5206
# Epoch 455/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7634 - loss: 0.5220
# Epoch 456/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7595 - loss: 0.5258
# Epoch 457/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7625 - loss: 0.5174
# Epoch 458/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7553 - loss: 0.5274
# Epoch 459/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7650 - loss: 0.5233
# Epoch 460/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7726 - loss: 0.5109
# Epoch 461/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7587 - loss: 0.5175
# Epoch 462/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7662 - loss: 0.5081
# Epoch 463/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7629 - loss: 0.5143
# Epoch 464/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7639 - loss: 0.5244
# Epoch 465/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7624 - loss: 0.5149
# Epoch 466/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7618 - loss: 0.5148
# Epoch 467/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7654 - loss: 0.5162
# Epoch 468/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7652 - loss: 0.5221
# Epoch 469/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7556 - loss: 0.5221
# Epoch 470/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7642 - loss: 0.5183
# Epoch 471/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7544 - loss: 0.5254
# Epoch 472/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7582 - loss: 0.5328
# Epoch 473/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7499 - loss: 0.5421
# Epoch 474/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7648 - loss: 0.5222
# Epoch 475/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7699 - loss: 0.5151
# Epoch 476/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7464 - loss: 0.5462
# Epoch 477/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7563 - loss: 0.5320
# Epoch 478/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7627 - loss: 0.5178
# Epoch 479/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7689 - loss: 0.5159
# Epoch 480/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7693 - loss: 0.5048
# Epoch 481/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7700 - loss: 0.5030
# Epoch 482/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7573 - loss: 0.5257
# Epoch 483/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7544 - loss: 0.5264
# Epoch 484/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7633 - loss: 0.5205
# Epoch 485/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7659 - loss: 0.5146
# Epoch 486/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7543 - loss: 0.5230
# Epoch 487/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7740 - loss: 0.5107
# Epoch 488/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7644 - loss: 0.5225
# Epoch 489/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7603 - loss: 0.5222
# Epoch 490/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7711 - loss: 0.5141
# Epoch 491/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7546 - loss: 0.5282
# Epoch 492/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7730 - loss: 0.4995
# Epoch 493/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7609 - loss: 0.5233
# Epoch 494/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7560 - loss: 0.5170
# Epoch 495/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7655 - loss: 0.5150
# Epoch 496/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7617 - loss: 0.5200
# Epoch 497/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7705 - loss: 0.5038
# Epoch 498/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7675 - loss: 0.5111
# Epoch 499/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7683 - loss: 0.5104
# Epoch 500/500
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7673 - loss: 0.5119

# %%
X_test =X_test.astype(float)

# %%
'''vcf = VanillaCF(config={'n_steps': 1000, 'lr': 0.05})
cf = vcf.generate_cf(X_test[:1].values, model1.pred_fn,permit_int =True)'''
#assert cf.shape == y_test[0].shape

# %%
'''data_module = DataModule.from_numpy(df_suic.drop(columns='Suicidio').values, df_suic.Suicidio.values)
exps = generate_cf_explanations(vcf, data_module, model1.pred_fn)
benchmark_cfs([exps])'''

# %%
'''import pandas as pd
import numpy as np

def save_counterfactuals_to_dataframe(explanation, data, pred_fn):
    # Extracting the original data (features and target values)
    original_data = data.xs  # Original features
    original_target = pred_fn(data.xs)  # Original target values (previsões)

    # Extracting the counterfactual data (features and counterfactual predictions)
    cfs = explanation.cfs  # Counterfactuals
    counterfactual_target = pred_fn(cfs)  # Predições para os contrafactuais

    # Verifique as dimensões para garantir que são 1D antes de adicioná-las ao DataFrame
    # Caso as features sejam 2D (como uma matriz), achate-as
    if original_data.ndim > 1:
        original_data = original_data.flatten()  # Achatar para 1D
    if cfs.ndim > 1:
        cfs = cfs.flatten()  # Achatar para 1D

    # Convert counterfactuals and original data into a dataframe
    data_dict = {
        "original_features": original_data.tolist(),
        "original_target": original_target.tolist(),
        "counterfactual_features": cfs.tolist(),
        "counterfactual_target": counterfactual_target.tolist()
    }

    # Criar o DataFrame com os dados
    df = pd.DataFrame(data_dict)

    # Se você tiver múltiplas colunas de features, pode expandir da seguinte forma
    for i in range(original_data.shape[1]):  # Caso seja um array multidimensional
        df[f"original_feature_{i}"] = original_data[:, i]
        df[f"counterfactual_feature_{i}"] = cfs[:, i]

    return df

# Chamada da função e armazenamento dos resultados em um DataFrame
explanation = generate_cf_explanations(vcf, data_module, model1.pred_fn)
df = save_counterfactuals_to_dataframe(explanation, data_module, model1.pred_fn)

# Visualizar o DataFrame
print(df.head())'''

# %%
 # Extracting the original data (features and target values)
'''original_data = data_module.xs  # Original features
original_target = pred_fn(data.xs)  # Original target values (previsões)

    # Extracting the counterfactual data (features and counterfactual predictions)
cfs = explanation.cfs  # Counterfactuals
counterfactual_target = pred_fn(cfs)  # Predições para os contrafactuais

    # Verifique as dimensões para garantir que são 1D antes de adicioná-las ao DataFrame
    # Caso as features sejam 2D (como uma matriz), achate-as
if original_data.ndim > 1:
        original_data = original_data.flatten()  # Achatar para 1D
if cfs.ndim > 1:
        cfs = cfs.flatten()  # Achatar para 1D

    # Convert counterfactuals and original data into a dataframe
data_dict = {
        "original_features": original_data.tolist(),
        "original_target": original_target.tolist(),
        "counterfactual_features": cfs.tolist(),
        "counterfactual_target": counterfactual_target.tolist()
    }

    # Criar o DataFrame com os dados
df = pd.DataFrame(data_dict)

    # Se você tiver múltiplas colunas de features, pode expandir da seguinte forma
for i in range(original_data.shape[1]):  # Caso seja um array multidimensional
        df[f"original_feature_{i}"] = original_data[:, i]
        df[f"counterfactual_feature_{i}"] = cfs[:, i]


# Chamada da função e armazenamento dos resultados em um DataFrame
explanation = generate_cf_explanations(vcf, data_module, model1.pred_fn)
df = save_counterfactuals_to_dataframe(explanation, data_module, model1.pred_fn)'''

# %%
from sklearn.model_selection import train_test_split
from relax.methods import VanillaCF
import numpy as np
import jax.numpy as jnp

# Definir a configuração do VanillaCF
vcf = VanillaCF(config={'n_steps': 1000, 'lr': 0.05})

# Converter DataFrame para NumPy para evitar strings como índices
X_test_np = X_test.values

# Mapear índices numéricos para os intervalos categóricos correspondentes
feature_ranges = {
    0: [0, 1],  # Suic_familia
    1: [0, 1],  # Dep_familia
    2: [0, 1],  # Estudante
    3: [0, 1],  # Alc_familia
    4: [1, 5],  # Capaz de tomar decisões importantes
    5: [1, 5],  # Capaz de desfrutar das coisas
    6: [0, 4],  # Hipocondriase
    7: [0, 4],  # Sentimentos_culpa
    8: [0, 4],  # Trabalho e interesses
    9: [0, 2]   # Droga
}

def round_to_category(values, feature_ranges):
    values_jax = jnp.array(values)  # Converte para um array JAX
    for feature_idx, ranges in feature_ranges.items():
        # Arredondar e aplicar limite, retornando um novo array JAX imutável
        values_jax = values_jax.at[:, feature_idx].set(
            jnp.round(values_jax[:, feature_idx]).clip(ranges[0], ranges[-1])
        )
    return values_jax

# Função para gerar e ajustar contrafactuais
def generate_and_adjust_cf(vcf, X_test_np, pred_fn, feature_ranges):
    cf_result = vcf.generate_cf(X_test_np[:1], model1.pred_fn, permit_int=True)
    cf_adjusted = round_to_category(cf_result, feature_ranges)
    return cf_adjusted

# Gerar e ajustar os contrafactuais
cf = generate_and_adjust_cf(vcf, X_test_np, model1, feature_ranges)

# Preparar o DataModule e gerar explicações contrafactuais com o ReLax
data_module = DataModule.from_numpy(X.values, y.values)
exps = generate_cf_explanations(vcf, data_module, model1.pred_fn)

# Executar o benchmark
benchmark_cfs([exps])
# Out:
# Running for 1,000 iterations:   0%|          | 0/1000 [00:00<?, ?it/s]
# Running for 1,000 iterations:   0%|          | 0/1000 [00:00<?, ?it/s]
#                            acc  validity  proximity
# Explanation VanillaCF  0.75664  0.806729   4.229963

# %%
import pandas as pd
import numpy as np

def round_to_category(values, feature_ranges):
    values_jax = jnp.array(values)  # Converte para um array JAX
    for feature_idx, ranges in feature_ranges.items():
        # Arredondar e aplicar limite, retornando um novo array JAX imutável
        values_jax = values_jax.at[:, feature_idx].set(
            jnp.round(values_jax[:, feature_idx]).clip(ranges[0], ranges[-1])
        )
    return values_jax

# 2. Converter os contrafactuais contínuos para categóricos
cfs_continuous = exps.cfs
cfs_categorical = round_to_category(cfs_continuous, feature_ranges)

# Supondo que 'cfs_categorical' seja um array tridimensional como mostrado
# Primeiro, vamos fazer a conversão para uma forma bidimensional (n_samples, n_features)
cfs_categorical_reshaped = cfs_categorical.squeeze()  # Remove a dimensão extra

# Agora, mapeia os índices de features originais para suas versões contrafactuais
original_features = df_suic.drop(columns=['Suicidio']).values

# Predição do target para os contrafactuais
# Supondo que o modelo esteja em 'model1'
predicted_target_cf = model1.pred_fn(cfs_categorical_reshaped)

# Salvando o DataFrame com as informações
df_result = pd.DataFrame({
    'ID': df_suic.index,  # ID do índice original de `df_suic`
})

# Adicionando as features originais e contrafactuais com sufixo '_cf'
for i, feature_name in enumerate(df_suic.drop(columns=['Suicidio']).columns):
    # Coluna para a feature original
    df_result[feature_name] = original_features[:, i]
    # Coluna para a feature contrafactual com o sufixo '_cf'
    df_result[f'{feature_name}_cf'] = cfs_categorical_reshaped[:, i]

# Adicionando os valores de 'Suicidio' original e predito para contrafactuais
df_result['Suicidio_Original'] = df_suic['Suicidio'].values

# Obter a classe com a maior probabilidade (classe com maior valor de probabilidade)
predicted_target_cf_class = np.argmax(predicted_target_cf, axis=1)

# Isso retorna o índice da classe com maior probabilidade para cada amostra.
# Se o seu target for multi-classe e as classes forem 0 e 1, predicted_target_cf_class será um array de 0s e 1s.

# Agora podemos adicionar isso ao DataFrame
df_result['Suicidio_CF'] = predicted_target_cf_class

# %%
df_result['Suicidio_CF'].value_counts()
# Out:
# Suicidio_CF
# 1    3189
# 0     764
# Name: count, dtype: int64

# %%
'''import pandas as pd
import numpy as np


def round_to_category(values, feature_ranges):
    values_jax = jnp.array(values)  # Converte para um array JAX
    for feature_idx, ranges in feature_ranges.items():
        # Arredondar e aplicar limite, retornando um novo array JAX imutável
        values_jax = values_jax.at[:, feature_idx].set(
            jnp.round(values_jax[:, feature_idx]).clip(ranges[0], ranges[-1])
        )
    return values_jax

# 2. Converter os contrafactuais contínuos para categóricos
cfs_continuous = exps.cfs
cfs_categorical = round_to_category(cfs_continuous, feature_ranges)

# 3. Obter o target predito para cada contrafactual
predicted_target_cf = model1.pred_fn(cfs_categorical)

# 4. Construir o DataFrame final
# Assumindo que X_test é o conjunto original das features categóricas e y_test o target original
df_result = pd.DataFrame({
    'ID': df_suic.index,  # ID do índice original de `df_suic`
    'Original_Features': list(df_suic.drop(columns=['Suicidio']).values),  # Features originais categóricas
    'CF_Features': list(cfs_categorical),      # Features contrafactuais ajustadas para categorias
    'Suicidio_Original': df_suic.Suicidio.values,          # Target original
    'Suicidio_CF': predicted_target_cf  # Target predito após contrafactual
})

# Opcional: Expanda as colunas para facilitar a leitura
df_result = df_result.explode(['Original_Features', 'CF_Features'])

# Exibir o DataFrame final
print(df_result)'''
